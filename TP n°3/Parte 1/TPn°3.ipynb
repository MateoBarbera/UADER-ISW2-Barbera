# %% [markdown]
# 2). 3). 4)

# %%
 pi = 3.14
print("Es el primer bloque del proyecto")
# Out:
# Es el primer bloque del proyecto

# %%
print("Es el segundo bloque del proyecto")
print(pi)
# Out:
# Es el segundo bloque del proyecto
# 3.14

# %% [markdown]
# 5)

# %% [markdown]
# lo que paso es que al reiniciarse el kernel , debemos volver a ejecutar la primer celda donde se encuentra definida pi, y luego podremos volver a ejecutar la segunda celda

# %% [markdown]
# 6)
#
# **Interrupt**: Interrumpe la ejecución del cuaderno.
# **Restart**: Reinicializa el cuaderno pero no borra los mensajes de salida de cada celda que se haya ejecutado.
# **Restart & Clear Output**: Reinicializa el cuaderno y borra los mensajes de salida de cada celda que se haya ejecutado.

# %% [markdown]
# 7)
#
# Lo que hace es indicar el orden en que se ejecutan las celdas

# %% [markdown]
# 8)

# %% [markdown]
# # Universidad Autónoma de Entre Ríos
# ## Facultad de Ciencia y Tecnología
# ### Sede Concepción del Uruguay
# Licenciatura en Sistema de Información:
# - Primer año
# - Segundo año
# - **Tercer** año
# - Cuarto año
# - Quinto año

# %% [markdown]
# 9)

# %% [markdown]
# ![Imagen](https://static.eldiario.es/clip/619daede-4610-479e-9710-d2a9c372bfbb_16-9-aspect-ratio_default_0.jpg)

# %% [markdown]
# 10)

# %% [markdown]
# Debemos crear una celda markdown y luego arrastrar la imagen elegida desde nuestro equipo hasta la celda

# %% [markdown]
# ![619daede-4610-479e-9710-d2a9c372bfbb_16-9-aspect-ratio_default_0.jpg](attachment:0cb69960-d211-4fc2-80b9-590eb1283320.jpg)

# %% [markdown]
# 11)

# %% [markdown]
# Para cambiar el orden de las celdas solo nesecitamos hacer click sobre ellas y arrastrarlas al lugar que querramos, y para combinarlas solo hay que hacer click derecho sobre alguna de las opciones que digan merge.

# %% [markdown]
#  Parte 2
